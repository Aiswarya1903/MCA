# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report

# %%
iris=datasets.load_iris()

# %%
x=iris.data
y=iris.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
classifier=KNeighborsClassifier(3)

# %%
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=classifier.predict(x_test)
for i in range(10):
    print(f"predicted:{iris.target_names[y_pred[i]]},Actual:{iris.target_names[y_test[i]]}")
# Out:
# predicted:virginica,Actual:virginica
# predicted:setosa,Actual:setosa
# predicted:virginica,Actual:virginica
# predicted:versicolor,Actual:versicolor
# predicted:virginica,Actual:virginica
# predicted:virginica,Actual:virginica
# predicted:versicolor,Actual:versicolor
# predicted:setosa,Actual:setosa
# predicted:versicolor,Actual:versicolor
# predicted:virginica,Actual:virginica

# %%
#accuracy check

accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9555555555555556

# %%
#classification report
cl=classification_report(y_test,y_pred,target_names=iris.target_names)
print(cl)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        16
#   versicolor       1.00      0.89      0.94        19
#    virginica       0.83      1.00      0.91        10
#
#     accuracy                           0.96        45
#    macro avg       0.94      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
result=classifier.predict([[3,5,6,7]])
print(iris.target_names[result])
# Out:
# ['virginica']

# %%
import matplotlib.pyplot as plt

plt.subplot(1,2,1)
plt.title("Predicted values")
plt.scatter(x_test[:,0],x_test[:,1],c=y_pred)
plt.xlabel("sepal length")
plt.ylabel("petal width")
plt.subplot(1,2,2)
plt.title("actual values")
plt.scatter(x_test[:,0],x_test[:,1],c=y_test)
plt.xlabel("sepal length")
plt.ylabel("petal length")
plt.legend()
# Out:
# C:\Users\AISWARYA A\AppData\Local\Temp\ipykernel_129864\3965796676.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
